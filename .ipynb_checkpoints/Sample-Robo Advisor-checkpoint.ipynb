# %% [markdown]
# # Robo Advisor - Dashboard

# %% [markdown]
# ## Content
# * [1. Loading the Libraries and the data](#1)
# * [2. Code for the dashboard Interface](#2)
# * [3. Code for the underlying functions within the interface](#3)
#
#
# #### Note that the dashboard opens up in a separate browser. The url for the browser will be produced in the end of the code and would look something like "http://127.0.0.1:8080"

# %% [markdown]
# <a id='1'></a>
# ## 1. Loading the Libraries and the data

# %% [markdown]
# Checking if the additional packages needed are present, if not install them. These are checked separately as they aren't included in requirement.txt as they aren't used for all case studies.

# %%
import pkg_resources
import pip
installedPackages = {pkg.key for pkg in pkg_resources.working_set}
required = {'dash', 'dash-core-components', 'dash-html-components', 'dash-daq', 'cvxopt' }
missing = required - installedPackages
if missing:
    # !pip install dash==1.9.1
    # !pip install dash-core-components==1.8.1
    # !pip install dash-html-components==1.0.2
    # !pip install dash-daq==0.4.0
    # !pip install cvxopt==1.2.5
# Out:
# Collecting dash==1.9.1
#   Downloading https://files.pythonhosted.org/packages/12/58/3f0e061150d2aee6501747e7ba0d3486461a3470aba556eca5b659c5733b/dash-1.9.1.tar.gz (64kB)
#      |████████████████████████████████| 71kB 737kB/s eta 0:00:01
# Requirement already satisfied: Flask>=1.0.2 in /Users/shirin/opt/anaconda3/lib/python3.7/site-packages (from dash==1.9.1) (1.1.1)
# Requirement already satisfied: flask-compress in /Users/shirin/opt/anaconda3/lib/python3.7/site-packages (from dash==1.9.1) (1.5.0)
# Requirement already satisfied: plotly in /Users/shirin/opt/anaconda3/lib/python3.7/site-packages (from dash==1.9.1) (4.8.1)
# Collecting dash_renderer==1.2.4 (from dash==1.9.1)
#   Downloading https://files.pythonhosted.org/packages/12/38/6ca3478c05420b2ed9c6ef42bc59a6fa487b3cd0125de7e253e84246559f/dash_renderer-1.2.4.tar.gz (1.1MB)
#      |████████████████████████████████| 1.1MB 4.2MB/s eta 0:00:01     |██████▋                         | 235kB 4.2MB/s eta 0:00:01
# Collecting dash-core-components==1.8.1 (from dash==1.9.1)
#   Downloading https://files.pythonhosted.org/packages/d8/ef/950e7d6dd3429925104406df996758bf6fd309c88d4c2ca34ecd77a847f5/dash_core_components-1.8.1.tar.gz (3.3MB)
#      |████████████████████████████████| 3.3MB 5.2MB/s eta 0:00:01
# Collecting dash-html-components==1.0.2 (from dash==1.9.1)
#   Downloading https://files.pythonhosted.org/packages/b4/9e/76988b02d09268495218639ad45dbfafe7dec8a52961278aeedaffb638ea/dash_html_components-1.0.2.tar.gz (187kB)
#      |████████████████████████████████| 194kB 4.5MB/s eta 0:00:01
# Collecting dash-table==4.6.1 (from dash==1.9.1)
#   Downloading https://files.pythonhosted.org/packages/7e/55/cd272ee8309c97666bffb12318ff3066bbc1936095e95af92507d452b083/dash_table-4.6.1.tar.gz (1.8MB)
#      |████████████████████████████████| 1.8MB 4.9MB/s eta 0:00:01
# Requirement already satisfied: future in /Users/shirin/opt/anaconda3/lib/python3.7/site-packages (from dash==1.9.1) (0.17.1)
# Requirement already satisfied: itsdangerous>=0.24 in /Users/shirin/opt/anaconda3/lib/python3.7/site-packages (from Flask>=1.0.2->dash==1.9.1) (1.1.0)
# Requirement already satisfied: Werkzeug>=0.15 in /Users/shirin/opt/anaconda3/lib/python3.7/site-packages (from Flask>=1.0.2->dash==1.9.1) (0.16.0)
# Requirement already satisfied: Jinja2>=2.10.1 in /Users/shirin/opt/anaconda3/lib/python3.7/site-packages (from Flask>=1.0.2->dash==1.9.1) (2.10.3)
# Requirement already satisfied: click>=5.1 in /Users/shirin/opt/anaconda3/lib/python3.7/site-packages (from Flask>=1.0.2->dash==1.9.1) (7.0)
# Requirement already satisfied: brotli in /Users/shirin/opt/anaconda3/lib/python3.7/site-packages (from flask-compress->dash==1.9.1) (1.0.7)
# Requirement already satisfied: six in /Users/shirin/opt/anaconda3/lib/python3.7/site-packages (from plotly->dash==1.9.1) (1.12.0)
# Requirement already satisfied: retrying>=1.3.3 in /Users/shirin/opt/anaconda3/lib/python3.7/site-packages (from plotly->dash==1.9.1) (1.3.3)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/shirin/opt/anaconda3/lib/python3.7/site-packages (from Jinja2>=2.10.1->Flask>=1.0.2->dash==1.9.1) (1.1.1)
# Building wheels for collected packages: dash, dash-renderer, dash-core-components, dash-html-components, dash-table
#   Building wheel for dash (setup.py) ... done
#   Created wheel for dash: filename=dash-1.9.1-cp37-none-any.whl size=71514 sha256=8cc816f4aea397ead37195c0f056429069b470480b159c2d9c2f103f069a3ad9
#   Stored in directory: /Users/shirin/Library/Caches/pip/wheels/ae/29/73/dd1e3699c9b9e5488b9688fed5d990364317c8472004f8df0b
#   Building wheel for dash-renderer (setup.py) ... done
#   Created wheel for dash-renderer: filename=dash_renderer-1.2.4-cp37-none-any.whl size=1146885 sha256=dafc9ffa3f387cffd03508c592c05c81a6f2d5692616bc8e4209b4aa85da4889
#   Stored in directory: /Users/shirin/Library/Caches/pip/wheels/1b/91/5e/af35d118f1c25482e973db760534c3c3666287ab687059a1a4
#   Building wheel for dash-core-components (setup.py) ... done
#   Created wheel for dash-core-components: filename=dash_core_components-1.8.1-cp37-none-any.whl size=3395725 sha256=9832c68fb334204ce90289b5aba701a659196dd6d84470ad36e5bb2b25e755c7
#   Stored in directory: /Users/shirin/Library/Caches/pip/wheels/e6/bb/a2/28ba307164585367dd524d2a8ce039d3f41ea2eb0c025ce32b
#   Building wheel for dash-html-components (setup.py) ... done
#   Created wheel for dash-html-components: filename=dash_html_components-1.0.2-cp37-none-any.whl size=427903 sha256=1c28050cda7be8f301522e904d9c894c9933e4aac89e1a9b4a1b7ca4ec731b0d
#   Stored in directory: /Users/shirin/Library/Caches/pip/wheels/59/6d/79/e8fbded6c6102c00ef0d58a278a488d913d30c51ae95dbef90
#   Building wheel for dash-table (setup.py) ... done
#   Created wheel for dash-table: filename=dash_table-4.6.1-cp37-none-any.whl size=1765779 sha256=e50a550b1092c57f5b7e7096cf554b6372ab2aa161ed4b099cb04221ddc58382
#   Stored in directory: /Users/shirin/Library/Caches/pip/wheels/33/2b/63/5833408d184e067a28786814044c69c1b269a2945afd436649
# Successfully built dash dash-renderer dash-core-components dash-html-components dash-table
# Installing collected packages: dash-renderer, dash-core-components, dash-html-components, dash-table, dash
#   Found existing installation: dash-renderer 1.5.0
#     Uninstalling dash-renderer-1.5.0:
#       Successfully uninstalled dash-renderer-1.5.0
#   Found existing installation: dash-core-components 1.10.1
#     Uninstalling dash-core-components-1.10.1:
#       Successfully uninstalled dash-core-components-1.10.1
#   Found existing installation: dash-html-components 1.0.3
#     Uninstalling dash-html-components-1.0.3:
#       Successfully uninstalled dash-html-components-1.0.3
#   Found existing installation: dash-table 4.8.1
#     Uninstalling dash-table-4.8.1:
#       Successfully uninstalled dash-table-4.8.1
#   Found existing installation: dash 1.13.3
#     Uninstalling dash-1.13.3:
#       Successfully uninstalled dash-1.13.3
# Successfully installed dash-1.9.1 dash-core-components-1.8.1 dash-html-components-1.0.2 dash-renderer-1.2.4 dash-table-4.6.1
# Requirement already satisfied: dash-core-components==1.8.1 in /Users/shirin/opt/anaconda3/lib/python3.7/site-packages (1.8.1)
# Requirement already satisfied: dash-html-components==1.0.2 in /Users/shirin/opt/anaconda3/lib/python3.7/site-packages (1.0.2)
# Collecting dash-daq==0.4.0
#   Downloading https://files.pythonhosted.org/packages/74/e8/da75bb223a966460c4c4c1d789108578e22812dab7d557eb4df701821540/dash_daq-0.4.0.tar.gz (643kB)
#      |████████████████████████████████| 645kB 1.4MB/s eta 0:00:01
# Requirement already satisfied: dash>=1.6.1 in /Users/shirin/opt/anaconda3/lib/python3.7/site-packages (from dash-daq==0.4.0) (1.9.1)
# Requirement already satisfied: flask-compress in /Users/shirin/opt/anaconda3/lib/python3.7/site-packages (from dash>=1.6.1->dash-daq==0.4.0) (1.5.0)
# Requirement already satisfied: plotly in /Users/shirin/opt/anaconda3/lib/python3.7/site-packages (from dash>=1.6.1->dash-daq==0.4.0) (4.8.1)
# Requirement already satisfied: dash-renderer==1.2.4 in /Users/shirin/opt/anaconda3/lib/python3.7/site-packages (from dash>=1.6.1->dash-daq==0.4.0) (1.2.4)
# Requirement already satisfied: dash-core-components==1.8.1 in /Users/shirin/opt/anaconda3/lib/python3.7/site-packages (from dash>=1.6.1->dash-daq==0.4.0) (1.8.1)
# Requirement already satisfied: future in /Users/shirin/opt/anaconda3/lib/python3.7/site-packages (from dash>=1.6.1->dash-daq==0.4.0) (0.17.1)
# Requirement already satisfied: Flask>=1.0.2 in /Users/shirin/opt/anaconda3/lib/python3.7/site-packages (from dash>=1.6.1->dash-daq==0.4.0) (1.1.1)
# Requirement already satisfied: dash-html-components==1.0.2 in /Users/shirin/opt/anaconda3/lib/python3.7/site-packages (from dash>=1.6.1->dash-daq==0.4.0) (1.0.2)
# Requirement already satisfied: dash-table==4.6.1 in /Users/shirin/opt/anaconda3/lib/python3.7/site-packages (from dash>=1.6.1->dash-daq==0.4.0) (4.6.1)
# Requirement already satisfied: brotli in /Users/shirin/opt/anaconda3/lib/python3.7/site-packages (from flask-compress->dash>=1.6.1->dash-daq==0.4.0) (1.0.7)
# Requirement already satisfied: retrying>=1.3.3 in /Users/shirin/opt/anaconda3/lib/python3.7/site-packages (from plotly->dash>=1.6.1->dash-daq==0.4.0) (1.3.3)
# Requirement already satisfied: six in /Users/shirin/opt/anaconda3/lib/python3.7/site-packages (from plotly->dash>=1.6.1->dash-daq==0.4.0) (1.12.0)
# Requirement already satisfied: click>=5.1 in /Users/shirin/opt/anaconda3/lib/python3.7/site-packages (from Flask>=1.0.2->dash>=1.6.1->dash-daq==0.4.0) (7.0)
# Requirement already satisfied: Jinja2>=2.10.1 in /Users/shirin/opt/anaconda3/lib/python3.7/site-packages (from Flask>=1.0.2->dash>=1.6.1->dash-daq==0.4.0) (2.10.3)
# Requirement already satisfied: Werkzeug>=0.15 in /Users/shirin/opt/anaconda3/lib/python3.7/site-packages (from Flask>=1.0.2->dash>=1.6.1->dash-daq==0.4.0) (0.16.0)
# Requirement already satisfied: itsdangerous>=0.24 in /Users/shirin/opt/anaconda3/lib/python3.7/site-packages (from Flask>=1.0.2->dash>=1.6.1->dash-daq==0.4.0) (1.1.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/shirin/opt/anaconda3/lib/python3.7/site-packages (from Jinja2>=2.10.1->Flask>=1.0.2->dash>=1.6.1->dash-daq==0.4.0) (1.1.1)
# Building wheels for collected packages: dash-daq
#   Building wheel for dash-daq (setup.py) ... done
#   Created wheel for dash-daq: filename=dash_daq-0.4.0-cp37-none-any.whl size=662160 sha256=8ec72f2123eb73737d6026a6c23dd95b54ab54107b8b083a745c092b428e8081
#   Stored in directory: /Users/shirin/Library/Caches/pip/wheels/80/31/eb/458403eead0852789d6fef02f6527050e42d174d22e1482a75
# Successfully built dash-daq
# Installing collected packages: dash-daq
# Successfully installed dash-daq-0.4.0
# Collecting cvxopt==1.2.5
#   Downloading https://files.pythonhosted.org/packages/92/fa/10beeb4c6ea4d89f1154c7273a907cab5ce3345f4ac4aa716b21a17502f3/cvxopt-1.2.5-cp37-cp37m-macosx_10_9_x86_64.whl (3.1MB)
#      |████████████████████████████████| 3.1MB 1.3MB/s eta 0:00:01    |▌                               | 51kB 901kB/s eta 0:00:04
# Installing collected packages: cvxopt
# Successfully installed cvxopt-1.2.5

# %% [markdown]
# Importing the packages needed

# %%
import dash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input,Output,State
import pandas as pd
import numpy as np
import plotly.graph_objs as go
import dash_daq as daq
from pickle import load
import cvxopt as opt
from cvxopt import blas, solvers

# %% [markdown]
# ### Load the data of the investors/individuals

# %%
# df.head()
investors = pd.read_csv('InputData.csv', index_col = 0 )
investors.head(1)
# Out:
#    AGE07  EDCL07  MARRIED07  KIDS07  LIFECL07  OCCAT107      INCOME07  RISK07  \
# 0     47       2          1       0         2         1  56443.744181       3
#
#    WSAVED07  SPENDMOR07   NETWORTH07  TrueRiskTol
# 0         1           5  352641.7113     6.947439

# %% [markdown]
# ### Load the market data and clean the data

# %%
assets = pd.read_csv('SP500Data.csv',index_col=0)
missing_fractions = assets.isnull().mean().sort_values(ascending=False)

missing_fractions.head(10)

drop_list = sorted(list(missing_fractions[missing_fractions > 0.3].index))

assets.drop(labels=drop_list, axis=1, inplace=True)
assets.shape
# Fill the missing values with the last value available in the dataset. 
assets=assets.fillna(method='ffill')
assets.head(2)
# Out:
#                   ABT       ABBV        ABMD         ACN       ATVI  \
# Date
# 2018-01-02  58.790001  98.410004  192.490005  153.839996  64.309998
# 2018-01-03  58.919998  99.949997  195.820007  154.550003  65.309998
#
#                   ADBE    AMD         AAP    AES         AMG  ...        WLTW  \
# Date                                                          ...
# 2018-01-02  177.699997  10.98  106.089996  10.88  203.039993  ...  146.990005
# 2018-01-03  181.039993  11.55  107.050003  10.87  202.119995  ...  149.740005
#
#                   WYNN        XEL        XRX       XLNX        XYL        YUM  \
# Date
# 2018-01-02  164.300003  47.810001  29.370001  67.879997  68.070000  81.599998
# 2018-01-03  162.520004  47.490002  29.330000  69.239998  68.900002  81.529999
#
#                    ZBH       ZION        ZTS
# Date
# 2018-01-02  124.059998  50.700001  71.769997
# 2018-01-03  124.919998  50.639999  72.099998
#
# [2 rows x 498 columns]

# %%
options=np.array(assets.columns)
# str(options)
options = []

for tic in assets.columns:
    #{'label': 'user sees', 'value': 'script sees'}
    mydict = {}
    mydict['label'] = tic #Apple Co. AAPL
    mydict['value'] = tic
    options.append(mydict)

# %% [markdown]
# <a id='2'></a>
# ## 2. Code for the dashboard Interface

# %%
app = dash.Dash(__name__, external_stylesheets=['https://codepen.io/chriddyp/pen/bWLwgP.css'])

# %%
app.layout = html.Div([
    html.Div([ 
        #Dashboard Name
        html.Div([
            html.H3(children='Robo Advisor Dashboard'),
            html.Div([
                html.H5(children='Step 1 : Enter Investor Characteristics '),            
                ],style={'display': 'inline-block','vertical-align': 'top',  'width': '30%',\
                         'color':'black', 'background-color': 'LightGray'}), 
            html.Div([
                html.H5(children='Step 2 : Asset Allocation and portfolio performance'),            
                ],style={'display': 'inline-block', 'vertical-align': 'top',  \
                         'color':'white','horizontalAlign' : "left", 'width': '70%', 'background-color':'black'}), 
            ],style={'font-family': 'calibri'}),        
         
         #All the Investor Characteristics
                      
       #********************Demographics Features DropDown********
         html.Div([   
          html.Div([ 
            
            html.Label('Age:',style={'padding': 5}),
            dcc.Slider(
                id='Age',
                min = investors['AGE07'].min(),
                max = 70,
                marks={ 25: '25',35: '35',45: '45',55: '55',70: '70'},              
                value=25),   
            #html.Br(),
            
            html.Label('NetWorth:', style={'padding': 5}),
            dcc.Slider(
                id='Nwcat',
                #min = investors['NETWORTH07'].min(), 
                min = -1000000, max = 3000000,
                marks={-1000000: '-$1M',0: '0',500000: '$500K',1000000: '$1M',2000000: '$2M',},                
                value=10000),
            #html.Br(),
            html.Label('Income:', style={'padding': 5}),
            dcc.Slider(
                id='Inccl',
                #min = investors['INCOME07'].min(), max = investors['INCOME07'].max(),
                min = -1000000,
                max = 3000000,
                marks={-1000000: '-$1M',0: '0',500000: '$500K',1000000: '$1M',2000000: '$2M',},
                value=100000),
            
           # html.Br(),
            html.Label('Education Level (scale of 4):', style={'padding': 5}),
            dcc.Slider(
                id='Edu',
                min = investors['EDCL07'].min(), max = investors['EDCL07'].max(),
                marks={ 1: '1',2: '2',3: '3',4: '4'},
                value=2), 
            #html.Br(),
            html.Label('Married:', style={'padding': 5}),
            dcc.Slider(
                id='Married',
                min = investors['MARRIED07'].min(), max = investors['MARRIED07'].max(),
                marks={ 1: '1',2: '2'},
                value=1), 
            #html.Br(),
            html.Label('Kids:', style={'padding': 5}),
            dcc.Slider(
                id='Kids',
                min = investors['KIDS07'].min(), max = investors['KIDS07'].max(),
                #marks={ 1: '1',2: '2',3: '3',4: '4'},
                marks=[{'label': j, 'value': j} for j in investors['KIDS07'].unique()],
                value=3), 
            #html.Br(),
            html.Label('Occupation:', style={'padding': 5}),
            dcc.Slider(
                id='Occ',
                min = investors['OCCAT107'].min(), max = investors['OCCAT107'].max(),
                marks={ 1: '1',2: '2',3: '3',4: '4'},
                value=3),            
            #html.Br(),
            html.Label('Willingness to take Risk:', style={'padding': 5}),
            dcc.Slider(
                id='Risk',
                min = investors['RISK07'].min(), max = investors['RISK07'].max(),
                marks={ 1: '1',2: '2',3: '3',4: '4'},
                value=3), 
            #html.Br(),
            html.Button(id='investor_char_button',
                            n_clicks = 0,
                            children = 'Calculate Risk Tolerance',
                            style = {'fontSize': 14, 'marginLeft': '30px', 'color' : 'white',\
                                     'horizontal-align': 'left','backgroundColor': 'grey'}),             
            #html.Br(),            
              ],style={'width': '80%'}),           
            
            ],style={'width': '30%', 'font-family': 'calibri','vertical-align': 'top','display': 'inline-block'\
                     }),
#                     , "border":".5px black solid"}),

    # ********************Risk Tolerance Charts********            
       html.Div([    
               #html.H5(children='Step 2 : Enter the Instruments for the allocation portfolio'),  
        html.Div([
            html.Div([ 
                html.Label('Risk Tolerance (scale of 100) :', style={'padding': 5}),
                dcc.Input(id= 'risk-tolerance-text'),
               
                ],style={'width': '100%','font-family': 'calibri','vertical-align': 'top','display': 'inline-block'}),

            html.Div([ 
                html.Label('Select the assets for the portfolio:', style={'padding': 5}),
                dcc.Dropdown(
                        id='ticker_symbol',
                        options = options,
                        value = ['GOOGL', 'FB', 'GS','MS','GE','MSFT'], 
                        multi = True
                        # style={'fontSize': 24, 'width': 75}
                        ),
                html.Button(id='submit-asset_alloc_button',
                            n_clicks = 0,
                            children = 'Submit',
                            style = {'fontSize': 12, 'marginLeft': '25px','color' : 'white', 'backgroundColor': 'grey'}

                ), 
               ],style={'width': '100%','font-family': 'calibri','vertical-align': 'top','display': 'inline-block'}),
            ],style={'width': '100%','display': 'inline-block','font-family': 'calibri','vertical-align': 'top'}),
           
           html.Div([                
                html.Div([
                    dcc.Graph(id='Asset-Allocation'), 
                    ], style={'width': '50%', 'vertical-align': 'top', 'display': 'inline-block', \
                      'font-family': 'calibri', 'horizontal-align': 'right'}),
                html.Div([
                    dcc.Graph(id='Performance')
                    ], style={'width': '50%', 'vertical-align': 'top', 'display': 'inline-block', \
                      'font-family': 'calibri', 'horizontal-align': 'right'}),
                   ], style={'width': '100%', 'vertical-align': 'top', 'display': 'inline-block', \
                          'font-family': 'calibri', 'horizontal-align': 'right'}),          


        ], style={'width': '70%','display': 'inline-block','font-family': 'calibri','vertical-align': 'top', 'horizontal-align': 'right'}),
       ],style={'width': '70%','display': 'inline-block','font-family': 'calibri','vertical-align': 'top'}),               

  ])

# %% [markdown]
# <a id='3'></a>
# ## 3. Code for the underlying functions within the interface
#
# The steps performed are as follows:
#
# 1) Loading the regression model for predicting risk tolerance
#
# 2) Using markovitz mean variance analysis for asset allocation
#
# 3) Producing chart for the asset allocation and portfolio performance
#
# #### Click the url produced by this code to see the dashboard

# %%
def predict_riskTolerance(X_input):

    filename = 'finalized_model.sav'
    loaded_model = load(open(filename, 'rb'))
    # estimate accuracy on validation set
    predictions = loaded_model.predict(X_input)
    return predictions

#Asset allocation given the Return, variance
def get_asset_allocation(riskTolerance,stock_ticker):
    #ipdb.set_trace()
    assets_selected = assets.loc[:,stock_ticker]
    return_vec = np.array(assets_selected.pct_change().dropna(axis=0)).T
    n = len(return_vec)
    returns = np.asmatrix(return_vec)
    mus = 1-riskTolerance
    
    # Convert to cvxopt matrices
    S = opt.matrix(np.cov(return_vec))
    pbar = opt.matrix(np.mean(return_vec, axis=1))
    # Create constraint matrices
    G = -opt.matrix(np.eye(n))   # negative n x n identity matrix
    h = opt.matrix(0.0, (n ,1))
    A = opt.matrix(1.0, (1, n))
    b = opt.matrix(1.0)
    # Calculate efficient frontier weights using quadratic programming
    portfolios = solvers.qp(mus*S, -pbar, G, h, A, b)
    w=portfolios['x'].T
    print (w)
    Alloc =  pd.DataFrame(data = np.array(portfolios['x']),index = assets_selected.columns)

    # Calculate efficient frontier weights using quadratic programming
    portfolios = solvers.qp(mus*S, -pbar, G, h, A, b)
    returns_final=(np.array(assets_selected) * np.array(w))
    returns_sum = np.sum(returns_final,axis =1)
    returns_sum_pd = pd.DataFrame(returns_sum, index = assets.index )
    returns_sum_pd = returns_sum_pd - returns_sum_pd.iloc[0,:] + 100   
    return Alloc,returns_sum_pd



#Callback for the graph
#This function takes all the inputs and computes the cluster and the risk tolerance


@app.callback(
     [Output('risk-tolerance-text', 'value')],
    [Input('investor_char_button', 'n_clicks'),
    Input('Age', 'value'),Input('Nwcat', 'value'),
    Input('Inccl', 'value'), Input('Risk', 'value'),
    Input('Edu', 'value'),Input('Married', 'value'),
    Input('Kids', 'value'),Input('Occ', 'value')])
#get the x and y axis details 

def update_risk_tolerance(n_clicks,Age,Nwcat,Inccl,Risk,Edu,Married,Kids,Occ):
      
    #ipdb.set_trace()
    
    RiskTolerance = 0
    if n_clicks != None:    
        X_input = [[Age,Edu,Married,Kids,Occ,Inccl, Risk,Nwcat]]
        RiskTolerance= predict_riskTolerance(X_input)
    #print(RiskAversion)
    #Using linear regression to get the risk tolerance within the cluster.    
    return list([round(float(RiskTolerance*100),2)])

@app.callback([Output('Asset-Allocation', 'figure'),
              Output('Performance', 'figure')],
            [Input('submit-asset_alloc_button', 'n_clicks'),
            Input('risk-tolerance-text', 'value')], 
            [State('ticker_symbol', 'value')
            ])
def update_asset_allocationChart(n_clicks, risk_tolerance, stock_ticker):
    
    Allocated, InvestmentReturn = get_asset_allocation(risk_tolerance,stock_ticker)  
    
    return [{'data' : [go.Bar(
                        x=Allocated.index,
                        y=Allocated.iloc[:,0],
                        marker=dict(color='red'),
                    ),
                    ],
            'layout': {'title':" Asset allocation - Mean-Variance Allocation"}

       },
            {'data' : [go.Scatter(
                        x=InvestmentReturn.index,
                        y=InvestmentReturn.iloc[:,0],
                        name = 'OEE (%)',
                        marker=dict(color='red'),
                    ),
                    ],
            'layout': {'title':"Portfolio value of $100 investment"}

       }]

if __name__ == '__main__':
    app.run_server()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [21/Oct/2020 16:11:25] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Oct/2020 16:11:25] "GET /_dash-component-suites/dash_renderer/polyfill@7.v1_2_2m1603289421.7.0.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Oct/2020 16:11:25] "GET /_dash-component-suites/dash_renderer/prop-types@15.v1_2_2m1603289421.7.2.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Oct/2020 16:11:25] "GET /_dash-component-suites/dash_renderer/react@16.v1_2_2m1603289421.8.6.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Oct/2020 16:11:25] "GET /_dash-component-suites/dash_renderer/react-dom@16.v1_2_2m1603289421.8.6.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Oct/2020 16:11:25] "GET /_dash-component-suites/dash_core_components/dash_core_components-shared.v1_8_1m1603289423.js HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Oct/2020 16:11:25] "GET /_dash-component-suites/dash_core_components/dash_core_components.v1_8_1m1603289423.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Oct/2020 16:11:25] "GET /_dash-component-suites/dash_html_components/dash_html_components.v1_0_2m1603289424.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Oct/2020 16:11:25] "GET /_dash-component-suites/dash_daq/dash_daq.v0_4_0m1603289444.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Oct/2020 16:11:25] "GET /_dash-component-suites/dash_renderer/dash_renderer.v1_2_2m1603289421.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Oct/2020 16:11:37] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Oct/2020 16:11:37] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Oct/2020 16:11:37] "GET /_favicon.ico?v=1.9.1 HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Oct/2020 16:11:37] "GET /_dash-component-suites/dash_core_components/async-slider.v1_8_1m1582838719.js HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Oct/2020 16:11:37] "GET /_dash-component-suites/dash_core_components/async-dropdown.v1_8_1m1582838719.js HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Oct/2020 16:11:37] "GET /_dash-component-suites/dash_core_components/async-graph.v1_8_1m1582838719.js HTTP/1.1" 200 -
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/shirin/opt/anaconda3/lib/python3.7/site-packages/flask/app.py", line 2446, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/shirin/opt/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1951, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/shirin/opt/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1820, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/shirin/opt/anaconda3/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/shirin/opt/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1949, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/shirin/opt/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1935, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/shirin/opt/anaconda3/lib/python3.7/site-packages/dash/dash.py", line 1461, in dispatch
#     response.set_data(self.callback_map[output]["callback"](*args))
#   File "/Users/shirin/opt/anaconda3/lib/python3.7/site-packages/dash/dash.py", line 1341, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-8-65339cb6bb55>", line 75, in update_asset_allocationChart
#     Allocated, InvestmentReturn = get_asset_allocation(risk_tolerance,stock_ticker)
#   File "<ipython-input-8-65339cb6bb55>", line 16, in get_asset_allocation
#     mus = 1-riskTolerance
# TypeError: unsupported operand type(s) for -: 'int' and 'NoneType'
# 127.0.0.1 - - [21/Oct/2020 16:11:37] "POST /_dash-update-component HTTP/1.1" 500 -
# 127.0.0.1 - - [21/Oct/2020 16:11:37] "GET /_dash-component-suites/dash_core_components/async-plotlyjs.v1_8_1m1582838719.js HTTP/1.1" 200 -
# /Users/shirin/opt/anaconda3/lib/python3.7/site-packages/sklearn/base.py:306: UserWarning: Trying to unpickle estimator DecisionTreeRegressor from version 0.21.2 when using version 0.21.3. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# /Users/shirin/opt/anaconda3/lib/python3.7/site-packages/sklearn/base.py:306: UserWarning: Trying to unpickle estimator RandomForestRegressor from version 0.21.2 when using version 0.21.3. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# /Users/shirin/opt/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/base.py:154: UserWarning: Loky-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   n_jobs = min(effective_n_jobs(n_jobs), n_estimators)
# 127.0.0.1 - - [21/Oct/2020 16:11:40] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Oct/2020 16:11:41] "POST /_dash-update-component HTTP/1.1" 200 -
#      pcost       dcost       gap    pres   dres
#  0: -2.2122e-03 -1.0030e+00  1e+00  4e-16  3e+00
#  1: -2.2131e-03 -1.3047e-02  1e-02  2e-16  3e-02
#  2: -2.3198e-03 -3.3551e-03  1e-03  3e-17  3e-03
# Terminated (singular KKT matrix).
# [ 1.78e-01  1.97e-01  1.43e-01  1.48e-01  1.40e-01  1.95e-01]
#
#      pcost       dcost       gap    pres   dres
#  0: -2.2122e-03 -1.0030e+00  1e+00  4e-16  3e+00
#  1: -2.2131e-03 -1.3047e-02  1e-02  2e-16  3e-02
#  2: -2.3198e-03 -3.3551e-03  1e-03  3e-17  3e-03
# Terminated (singular KKT matrix).
# /Users/shirin/opt/anaconda3/lib/python3.7/site-packages/sklearn/base.py:306: UserWarning: Trying to unpickle estimator DecisionTreeRegressor from version 0.21.2 when using version 0.21.3. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# /Users/shirin/opt/anaconda3/lib/python3.7/site-packages/sklearn/base.py:306: UserWarning: Trying to unpickle estimator RandomForestRegressor from version 0.21.2 when using version 0.21.3. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# /Users/shirin/opt/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/base.py:154: UserWarning: Loky-backed parallel loops cannot be nested below threads, setting n_jobs=1
#   n_jobs = min(effective_n_jobs(n_jobs), n_estimators)
# 127.0.0.1 - - [21/Oct/2020 16:11:51] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Oct/2020 16:11:52] "POST /_dash-update-component HTTP/1.1" 200 -
#      pcost       dcost       gap    pres   dres
#  0: -2.0904e-03 -1.0029e+00  1e+00  0e+00  3e+00
#  1: -2.0913e-03 -1.2946e-02  1e-02  5e-17  3e-02
#  2: -2.1959e-03 -3.1828e-03  1e-03  7e-17  3e-03
# Terminated (singular KKT matrix).
# [ 1.78e-01  1.95e-01  1.43e-01  1.48e-01  1.40e-01  1.96e-01]
#
#      pcost       dcost       gap    pres   dres
#  0: -2.0904e-03 -1.0029e+00  1e+00  0e+00  3e+00
#  1: -2.0913e-03 -1.2946e-02  1e-02  5e-17  3e-02
#  2: -2.1959e-03 -3.1828e-03  1e-03  7e-17  3e-03
# Terminated (singular KKT matrix).

# %% [markdown]
# ## Sample Dashboard
#
# <img src="RoboDashboard.png" width="1400" />
